# %% [markdown]
# # 起動時セットアップ
# 必ず実行すること。
#
# ---

# %%
# !pip install youtube_dl
# !rm -rv sample_data
# !rm -v *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# rm: cannot remove 'sample_data': No such file or directory
# removed 'c1rPcynQFvU.webm.part'
# removed '【ニコカラ】ダダダダ天使(Off Vocal)-c1rPcynQFvU.wav'
# removed '【ニコカラ】ダダダダ天使(Off Vocal).part'

# %% [markdown]
# # メインブロック
#
# ---

# %%
#@title 変換器

TYPE = 'wav' #@param ["mp3", "wav"] {allow-input: false}
URL = "https://www.youtube.com/watch?v=c1rPcynQFvU"#@param {type:"string"}

import youtube_dl
from google.colab import files

ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl':'%(title)s.' + TYPE,
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': TYPE,
        'preferredquality': '192',
    }],
}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    res = ydl.extract_info(URL, download=True)
    files.download("/content/" + res['title'] + "." + TYPE)
# Out:
# [youtube] c1rPcynQFvU: Downloading webpage
# [download] Destination: 【ニコカラ】ダダダダ天使(Off Vocal).wav
# [download] 100% of 3.59MiB in 01:26
# [ffmpeg] Post-process file 【ニコカラ】ダダダダ天使(Off Vocal).wav exists, skipping
